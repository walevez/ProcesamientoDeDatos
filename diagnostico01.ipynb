# %% [markdown]
# <a href="https://colab.research.google.com/github/walevez/ProcesamientoDeDatos/blob/main/diagnostico01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Extraigan un dataframe del csv NY-House-Dataset.csv y creen un programa en Python que siga las instrucciones:
#
#
#     importar el dataset con pandas
#     Responder:
#         Cuantas filas tiene el dataset?
#         Que tipos de datos tienen las columnas?
#         Cuales columnas son numericas y cuales son categoricas?
#         Si quisiera hacer un analisis de precio segun la localidad, que columnas eligiria para el analisis?
#         Cuantas casas son de Brooklyn?
#         Modificar la columna “Type” y reemplazar los espacios “ “ por guiones “-”
#
# Link a dataset
# Última modificación: jueves, 27 de agosto de 2026, 22:50

# %% [markdown]
# # Resolucion de la consigna

# %%
# importacion del las bibliotecas a usar
import pandas as pd

# %%
# descarga del archivo que usaremos para el dataset
! wget https://raw.githubusercontent.com/walevez/ProcesamientoDeDatos/refs/heads/main/datasets/NY-House-Dataset.csv
# Out:
# --2026-09-03 17:04:42--  https://raw.githubusercontent.com/walevez/ProcesamientoDeDatos/refs/heads/main/datasets/NY-House-Dataset.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1334269 (1.3M) [text/plain]
# Saving to: ‘NY-House-Dataset.csv.1’
#
# NY-House-Dataset.cs 100%[===================>]   1.27M  --.-KB/s    in 0.04s
#
# 2026-09-03 17:04:42 (31.6 MB/s) - ‘NY-House-Dataset.csv.1’ saved [1334269/1334269]

# %%
# creamos el dataset con el archivo que descargamos
df = pd.read_csv('/content/NY-House-Dataset.csv')

df
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  BEDS       BATH  PROPERTYSQFT  \
# ...

# %% [markdown]
# ### Analisis del dataset

# %% [markdown]
# ## Cuantas filas tiene el dataset?

# %%
# guardamos en la variable filas el primer valor que devuelve el metodo shape
# utilizandolo en el dataset df.
filas = df.shape[0]
print(f'El archivo tiene: {filas}')
# Out:
# El archivo tiene: 4801

# %% [markdown]
# ###

# %% [markdown]
# ## Que tipos de datos tienen las columnas?

# %%
# para obtener la descripcion de que tipos de datos tiene cada columna
# utilizo en metodo info en el dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  4801 non-null   object
#  1   TYPE                         4801 non-null   object
#  2   PRICE                        4801 non-null   int64
#  3   BEDS                         4801 non-null   int64
#  4   BATH                         4801 non-null   float64
#  5   PROPERTYSQFT                 4801 non-null   float64
#  6   ADDRESS                      4801 non-null   object
#  7   STATE                        4801 non-null   object
#  8   MAIN_ADDRESS                 4801 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  4801 non-null   object
#  10  LOCALITY                     4801 non-null   object
#  11  SUBLOCALITY                  4801 non-null   object
#  12  STREET_NAME                  4801 non-null   object
# ...

# %% [markdown]
# ## Cuales columnas son numericas y cuales son categoricas?

# %% [markdown]
# ### Columnas numericas:
# PRICE - BEDS - BATH - PROPERTSQFT
#
# ### Columnas categoricas:
# BROKERTITTLE - TYPE - ADDRESS - STATE - MAIN_ADDRESS - ADMINISTRATIVE_AREA_LEVEL_2 - LOCALITY - SUBLOCALITY - STREET_NAME - LONG_NAME - FORMATTED_ADDRESS - LATITUDE - LONGITUDE

# %% [markdown]
# ## Si quisiera hacer un analisis de precio segun la localidad, que columnas eligiria para el analisis?

# %% [markdown]
# Las columnas que se necesitan para hacer un analisis del precio por segun la localidad, eso:
#
# PRICE - LOCALITY

# %% [markdown]
# ## Cuantas casas son de Brooklyn?

# %%
# usamos el metodo suma, para sumar cada vez que el metodo sea verdadero.
count_brokling = (df['LOCALITY']=='Brooklyn').sum()
print(f'Hay {count_brokling} en Brooklyn')
# Out:
# Hay 6 en Brooklyn

# %% [markdown]
# ##

# %% [markdown]
# ## Modificar la columna “Type” y reemplazar los espacios “ “ por guiones “-”

# %%
# usamos el metodo replace.
df['TYPE']=df['TYPE'].str.replace(" ","-")
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo-for-sale
# 1                                Brokered by Serhant      Condo-for-sale
# 2                             Brokered by Sowae Corp      House-for-sale
# 3                                Brokered by COMPASS      Condo-for-sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse-for-sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...
