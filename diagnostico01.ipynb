# %% [markdown]
# <a href="https://colab.research.google.com/github/walevez/ProcesamientoDeDatos/blob/main/diagnostico01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Extraigan un dataframe del csv NY-House-Dataset.csv y creen un programa en Python que siga las instrucciones:
#
#
#     importar el dataset con pandas
#     Responder:
#         Cuantas filas tiene el dataset?
#         Que tipos de datos tienen las columnas?
#         Cuales columnas son numericas y cuales son categoricas?
#         Si quisiera hacer un analisis de precio segun la localidad, que columnas eligiria para el analisis?
#         Cuantas casas son de Brooklyn?
#         Modificar la columna “Type” y reemplazar los espacios “ “ por guiones “-”
#
# Link a dataset
# Última modificación: jueves, 27 de agosto de 2026, 22:50

# %%
link = 'https://campusissd.quinttos.com/pluginfile.php/65308/mod_page/content/1/NY-House-Dataset.csv'

# %% [markdown]
# # Resolucion de la consigna

# %%
# importacion del las bibliotecas a usar
import pandas as pd

# %%
# descarga del archivo que usaremos para el dataset
! wget 'https://campusissd.quinttos.com/pluginfile.php/65308/mod_page/content/1/NY-House-Dataset.csv'
# Out:
# --2026-09-03 00:06:50--  https://campusissd.quinttos.com/pluginfile.php/65308/mod_page/content/1/NY-House-Dataset.csv
# Resolving campusissd.quinttos.com (campusissd.quinttos.com)... 198.244.232.60
# Connecting to campusissd.quinttos.com (campusissd.quinttos.com)|198.244.232.60|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://campusissd.quinttos.com/login/index.php [following]
# --2026-09-03 00:06:51--  https://campusissd.quinttos.com/login/index.php
# Reusing existing connection to campusissd.quinttos.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘NY-House-Dataset.csv’
#
# NY-House-Dataset.cs     [ <=>                ]  26.13K  --.-KB/s    in 0.1s
#
# 2026-09-03 00:06:51 (268 KB/s) - ‘NY-House-Dataset.csv’ saved [26762]

# %%
# creamos el dataset con el archivo que descargamos
df = pd.read_csv('/content/NY-House-Dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_374/3648286888.py in <cell line: 0>()
#       1 # creamos el dataset con el archivo que descargamos
# ----> 2 df = pd.read_csv('/content/NY-House-Dataset.csv')
#
# ...

# %% [markdown]
# ### Analisis del dataset

# %% [markdown]
# ### Cuantas filas tiene el dataset?
